# %% [markdown]
# # Análise de Dados com Python
#
# ### Desafio:
#
# Você trabalha em uma empresa de telecom e tem clientes de vários serviços diferentes, entre os principais: internet e telefone.
#
# O problema é que, analisando o histórico dos clientes dos últimos anos, você percebeu que a empresa está com Churn de mais de 26% dos clientes.
#
# Isso representa uma perda de milhões para a empresa.
#
# O que a empresa precisa fazer para resolver isso?
#
# Base de Dados: https://drive.google.com/drive/folders/1T7D0BlWkNuy_MDpUHuBG44kT80EmRYIs?usp=sharing <br>
# Link Original do Kaggle: https://www.kaggle.com/radmirzosimov/telecom-users-dataset

# %%
import pandas as pd

tabela = pd.read_csv("transferoacademy_transações.csv", sep=";", encoding="latin-1")
display(tabela)
# Out:
#                 horario             Conta tipo de operação Moeda que Entrou  \
# 0      26/11/2020 00:33  conta da Binance            trade             USDT
# 1      26/11/2020 00:35  conta da Binance            trade             USDT
# 2      26/11/2020 00:35  conta da Binance            trade             USDT
# 3      26/11/2020 00:35  conta da Binance            trade             USDT
# 4      26/11/2020 00:35  conta da Binance            trade             USDT
# ...                 ...               ...              ...              ...
# 83657  30/12/2021 13:16  conta da Binance            trade              BRL
# 83658  30/12/2021 13:16  conta da Binance            trade              BRL
# 83659  30/12/2021 13:16  conta da Binance            trade              BRL
# 83660  30/12/2021 13:16  conta da Binance            trade              BRL
# 83661  30/12/2021 13:17  conta da Binance            trade              BRL
#
# ...

# %%
tabela["Moeda que Entrou"]

tipos_de_moedas_que_entrou = tabela["Moeda que Entrou"]

# %%
tipos_de_moedas_que_entrou.drop_duplicates()
# Out:
# 0          USDT
# 10          BTC
# 20          ETH
# 37          BRL
# 165        NEAR
# 339         XRP
# 360         NaN
# 561         LTC
# 8301       TUSD
# 8303        BCH
# 8403        CHZ
# 10969      BUSD
# 10986      DOGE
# 12779      USDC
# 13282       SOL
# 15536       BNB
# 21125       DAI
# 28090       ADA
# 32463       XLM
# 53723       EOS
# 54228      LINK
# 55296       FTT
# 66916       NKN
# 67918     ALICE
# 67921     ALPHA
# 67922        AR
# 67935      PERP
# 67939    BADGER
# 68322      KEEP
# 76108      ALGO
# 76109      AVAX
# 76119      MANA
# 76123     MATIC
# Name: Moeda que Entrou, dtype: object

# %%
tabela["Moeda que Saiu"]

tipos_de_moedas_que_saiu = tabela["Moeda que Saiu"]

# %%
tipos_de_moedas_que_saiu.drop_duplicates()
# Out:
# 0         BTC
# 5         ETH
# 10       USDT
# 38        BRL
# 142      BUSD
# 339       NaN
# 340       XRP
# 367       LTC
# 8305      CHZ
# 8310      DAI
# 11238    TUSD
# 11487     BCH
# 11511    DOGE
# 15532     BNB
# 15548    LINK
# 15682    USDC
# 53759     EOS
# 55281     FTT
# Name: Moeda que Saiu, dtype: object

# %% [markdown]
# ### Conclusões e Ações

# %% [markdown]
# Escreva aqui suas conclusões:
